# %%
with open('work.txt','w') as myfile:
    myfile.write('Written\n')
    myfile.write('New line is written\n')
    myfile.write('This id the second line\n')

with open('work.txt', 'r') as myfile:
    lines = myfile.readlines()

    for line in lines:
        req = line.strip()
    print(req)
# Out:
# This id the second line
